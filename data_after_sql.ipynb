# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

def get_dataset():
    data = pd.read_csv('Export.csv',sep=',',encoding='cp1252')
    return data 

dataset = get_dataset()
dataset.info()
dataset.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   entity                                 838 non-null    object
#  1   code                                   838 non-null    object
#  2   year                                   838 non-null    int64
#  3   all_death                              838 non-null    int64
#  4   neoplasms                              838 non-null    int64
#  5   ratio                                  838 non-null    float64
#  6   death_rate                             838 non-null    float64
#  7   gdp                                    796 non-null    float64
#  8   population                             838 non-null    int64
#  9   sales_of_cigarettes_per_adult_per_day  838 non-null    float64
# ...

# %% [markdown]
# В даному випадку джерело даних все "чисте" та приведено до найзрузнішого аналізу на поточний момент. Усі операції з перетвореннями були виконані в середовщі SQL (відповідні скрипти буде прикріплено).
